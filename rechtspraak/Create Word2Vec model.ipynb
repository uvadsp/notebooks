# %% [markdown]
# # Create dataset

# %% [markdown]
# ### Create

# %%
import pandas as pd
import os

# %%
dataPath = os.getcwd() + '/court case data/testdata/'
caseCount = len(os.listdir(dataPath))
data = []
try:
    os.remove(dataPath + ".DS_Store")
except:
    print("No file DS_Store")
for filename in os.listdir(dataPath):
    f = open(os.path.join(dataPath, filename), encoding='utf-8')
    data.append([filename.replace('.txt', ''), f.read()])

verdict_df = pd.DataFrame(data, columns=["id", "case text"])
cases_df = pd.read_csv('./court case data/testdata.csv')
merged_df = cases_df.join(verdict_df.set_index('id'), on='id', how='left')

merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# Out:
# No file DS_Store
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '23-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '13-04-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '28-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '21-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '19-12-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '21-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '29-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '16-01-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '27-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '19-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '26-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '29-04-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '19-09-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '27-10-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '16-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '16-05-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '17-02-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '31-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '19-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '29-01-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '17-10-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '31-01-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '19-08-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '13-05-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '18-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '25-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '14-02-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '27-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '18-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '14-09-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '30-03-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '22-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '24-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '18-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '22-08-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '18-04-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '23-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '26-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '15-05-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '22-04-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '26-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '24-11-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '25-02-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '28-07-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '16-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '29-04-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '14-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '17-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '30-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '18-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '22-07-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '25-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '20-08-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '18-07-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '29-08-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '23-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '27-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '23-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '16-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '29-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '22-01-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '24-11-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '26-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '27-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '29-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '23-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '14-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '30-09-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '20-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '20-06-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '22-07-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '27-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '20-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '20-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '26-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '21-12-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '21-10-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '15-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '28-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '18-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '16-07-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '18-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '20-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '27-08-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '29-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '16-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '30-03-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '20-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '17-01-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '18-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '13-12-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '21-08-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '22-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '27-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '15-09-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '18-06-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '13-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '21-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '26-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '14-03-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '30-12-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '13-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '16-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '27-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '19-02-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '21-04-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '25-07-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '15-04-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '26-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '21-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '21-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '25-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '27-09-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '13-04-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '23-01-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '21-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '16-08-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '23-12-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '19-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '18-04-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '22-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '27-09-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '30-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '13-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '30-05-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '15-05-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '24-12-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '18-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '25-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '15-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '27-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '21-11-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '22-06-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '17-02-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '30-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '20-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '28-08-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '31-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '23-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '21-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '30-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '24-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '24-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '15-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '16-04-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '26-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '27-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '20-12-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '28-06-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '13-08-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '16-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '15-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '25-02-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '27-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '28-06-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '29-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '15-07-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '25-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '24-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '27-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '14-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '26-06-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '17-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '29-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '26-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '23-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '28-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '16-09-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '21-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '20-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '13-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '28-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '17-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '21-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '13-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["verdict_date"] = pd.to_datetime(merged_df["verdict_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:16: UserWarning: Parsing '30-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
# ...
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '22-04-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '17-02-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '24-07-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '28-07-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '28-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '25-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '26-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '25-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '28-07-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '27-10-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '17-07-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '13-08-2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '15-06-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '22-01-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '18-07-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '18-04-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '25-01-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '29-06-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '22-01-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '18-09-2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '21-05-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '19-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '15-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '21-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '22-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '25-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '23-09-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '19-01-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '15-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '31-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '13-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '21-03-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '17-10-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '18-06-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '25-11-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '14-07-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '20-06-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '22-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '20-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '18-12-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '28-07-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '19-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '28-07-2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '19-10-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '29-07-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '26-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '21-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '20-01-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '15-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '23-05-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '28-05-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '24-12-2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '22-10-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '29-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '23-04-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])
# C:\Users\casbe\AppData\Local\Temp/ipykernel_13704/1144018101.py:17: UserWarning: Parsing '13-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   merged_df["publication_date"] = pd.to_datetime(merged_df["publication_date"])

# %%
def add_inhoudsindicatie_to_case_text(df):
    for index, row in df.iterrows():
        fulltext = row['case text'] + row['inhoudsindicatie']
        df.at[index,'case text']= fulltext
    return df

merged_df = add_inhoudsindicatie_to_case_text(merged_df)

# %%
merged_df.to_pickle("merged_df.pkl")

# %%
merged_df
# Out:
#                               id verdict_date publication_date verdict_type  \
# 0        ECLI-NL-RBNNE-2021-5018   2021-01-10       2021-11-23    uitspraak
# 1      ECLI-NL-RBZUT-2003-AH9598   2003-03-06       2003-09-07    uitspraak
# 2        ECLI-NL-RBZWB-2020-2646   2020-06-23       2020-06-23    uitspraak
# 3        ECLI-NL-GHAMS-2019-1601   2019-08-05       2019-07-26    uitspraak
# 4        ECLI-NL-GHAMS-2019-1602   2019-08-05       2019-07-26    uitspraak
# ...                          ...          ...              ...          ...
# 18457    ECLI-NL-RBAMS-2013-1294   2013-01-29       2013-08-10    uitspraak
# 18458      ECLI-NL-PHR-2020-1106   2020-11-24       2020-11-24    conclusie
# 18459    ECLI-NL-GHAMS-2017-2618   2017-06-29       2017-05-07    uitspraak
# 18460  ECLI-NL-RBAMS-2013-BZ0392   2013-01-29       2013-01-02    uitspraak
# 18461  ECLI-NL-GHAMS-2007-BB2447   2007-07-13       2007-08-29    uitspraak
#
#       jurisdiction_type                                   inhoudsindicatie  \
# 0        ['Strafrecht']  Productie synthetische drugs, medeplegen, prod...
# 1        ['Strafrecht']  Leveren grondstoffen synthetische drugs en sto...
# 2        ['Strafrecht']  plegen van voorbereidingshandelingen ten behoe...
# 3        ['Strafrecht']  medeplegen witwassen - medeplegen voorhanden h...
# 4        ['Strafrecht']  medeplegen witwassen - medeplegen voorhanden h...
# ...                 ...                                                ...
# 18457    ['Strafrecht']  De rechtbank acht bewezen dat er sprake is van...
# 18458    ['Strafrecht']  Conclusie AG. Vervolging van een politieagent ...
# 18459    ['Strafrecht']  Liquidatieproces Passage\n\n                  ...
# 18460    ['Strafrecht']  De rechtbank acht bewezen dat verdachte zich s...
# 18461    ['Strafrecht']  Verdachte en zijn medeverdachten hebben tezame...
#
#                                                case text
# 0      \n\nRECHTBANK NOORD-NEDERLAND\nAfdeling strafr...
# 1      \n\nRECHTBANK ZUTPHEN\nMeervoudige economische...
# 2      \n\nRECHTBANK ZEELAND-WEST-BRABANT\n\nStrafrec...
# 3      \n\nafdeling strafrecht\nparketnummer: 23-0017...
# 4      \n\nafdeling strafrecht\nparketnummer: 23-0017...
# ...                                                  ...
# 18457  \n\nRECHTBANK AMSTERDAM\n\n\nVONNIS\n\n \n\n13...
# 18458  \n\nPROCUREUR-GENERAAL\n\n\nBIJ DE\n\n\nHOGE R...
# 18459  \n\n\nparketnummer: 23-001217-13\ndatum uitspr...
# 18460  \nRECHTBANK AMSTERDAM \nVONNIS  \n\n13/529144-...
# 18461  \n\narrestnummer: \nparketnummer:\t23-001835-0...
#
# [18462 rows x 7 columns]

# %% [markdown]
# ### Load

# %%
import pandas as pd
import os

# %%
merged_df = pd.read_pickle("merged_df.pkl")
merged_df
# Out:
#                               id verdict_date publication_date verdict_type  \
# 0        ECLI-NL-RBNNE-2021-5018   2021-01-10       2021-11-23    uitspraak
# 1      ECLI-NL-RBZUT-2003-AH9598   2003-03-06       2003-09-07    uitspraak
# 2        ECLI-NL-RBZWB-2020-2646   2020-06-23       2020-06-23    uitspraak
# 3        ECLI-NL-GHAMS-2019-1601   2019-08-05       2019-07-26    uitspraak
# 4        ECLI-NL-GHAMS-2019-1602   2019-08-05       2019-07-26    uitspraak
# ...                          ...          ...              ...          ...
# 18457    ECLI-NL-RBAMS-2013-1294   2013-01-29       2013-08-10    uitspraak
# 18458      ECLI-NL-PHR-2020-1106   2020-11-24       2020-11-24    conclusie
# 18459    ECLI-NL-GHAMS-2017-2618   2017-06-29       2017-05-07    uitspraak
# 18460  ECLI-NL-RBAMS-2013-BZ0392   2013-01-29       2013-01-02    uitspraak
# 18461  ECLI-NL-GHAMS-2007-BB2447   2007-07-13       2007-08-29    uitspraak
#
#       jurisdiction_type                                   inhoudsindicatie  \
# 0        ['Strafrecht']  Productie synthetische drugs, medeplegen, prod...
# 1        ['Strafrecht']  Leveren grondstoffen synthetische drugs en sto...
# 2        ['Strafrecht']  plegen van voorbereidingshandelingen ten behoe...
# 3        ['Strafrecht']  medeplegen witwassen - medeplegen voorhanden h...
# 4        ['Strafrecht']  medeplegen witwassen - medeplegen voorhanden h...
# ...                 ...                                                ...
# 18457    ['Strafrecht']  De rechtbank acht bewezen dat er sprake is van...
# 18458    ['Strafrecht']  Conclusie AG. Vervolging van een politieagent ...
# 18459    ['Strafrecht']  Liquidatieproces Passage\n\n                  ...
# 18460    ['Strafrecht']  De rechtbank acht bewezen dat verdachte zich s...
# 18461    ['Strafrecht']  Verdachte en zijn medeverdachten hebben tezame...
#
#                                                case text
# 0      \n\nRECHTBANK NOORD-NEDERLAND\nAfdeling strafr...
# 1      \n\nRECHTBANK ZUTPHEN\nMeervoudige economische...
# 2      \n\nRECHTBANK ZEELAND-WEST-BRABANT\n\nStrafrec...
# 3      \n\nafdeling strafrecht\nparketnummer: 23-0017...
# 4      \n\nafdeling strafrecht\nparketnummer: 23-0017...
# ...                                                  ...
# 18457  \n\nRECHTBANK AMSTERDAM\n\n\nVONNIS\n\n \n\n13...
# 18458  \n\nPROCUREUR-GENERAAL\n\n\nBIJ DE\n\n\nHOGE R...
# 18459  \n\n\nparketnummer: 23-001217-13\ndatum uitspr...
# 18460  \nRECHTBANK AMSTERDAM \nVONNIS  \n\n13/529144-...
# 18461  \n\narrestnummer: \nparketnummer:\t23-001835-0...
#
# [18462 rows x 7 columns]

# %% [markdown]
# # Split sentences

# %%
import re

# %%
def split_into_sentences(text):
    sentences = re.split(r'(?<=[^A-Z].[.?]) +(?=[A-Z])|\n', text)
    sentences = [x for x in sentences if len(x) > 1]
    return sentences

# %%
sentence_list_by_word = []
sentence_list = []

for i in range(len(merged_df)):
    doc = merged_df.iloc[i]['case text']
    sentences = split_into_sentences(doc)
    sentence_list.append(sentences)
    for j in sentences:
        word_list = [x for x in j.lower().rstrip().replace('.', '').split(' ') if len(x)>0]
        sentence_list_by_word.append(word_list)
        


wordlen = 0
for i in sentence_list_by_word:
    wordlen += len(i)
    
print(f"Sentence count: {len(sentence_list_by_word)}")
print(f"Word count: {wordlen}")
# Out:
# Sentence count: 5301875
# Word count: 88748423

# %% [markdown]
# # Create Word2Vec model

# %%
from gensim.models import Word2Vec
from gensim.test.utils import common_texts

# %%
dutch_word2vec_model = Word2Vec(sentences=sentence_list_by_word, vector_size=100, window=5, min_count=1, workers=4)
dutch_word2vec_model.save("word2vec_dutch_court_cases.model")

# %%
dutch_word2vec_model = Word2Vec.load("word2vec_dutch_court_cases.model")

# %%
sims = dutch_word2vec_model.wv.most_similar('xtc', topn=100)
print([i[0] for i in sims])
# Out:
# ['mdma', 'speed', 'lsd', 'heroïne', 'amfetamine', 'ketamine', 'xtc-pillen', 'mdma)', 'ghb', 'amfetaminen', 'diazepam', 'methadon', 'xtc-tabletten', 'oxazepam', 'ecstasy', '(mdma)', 'morfine', 'xtc)', 'cocaïne', 'crack', 'cafeïne', 'pillen', 'methamfetamine', 'metamfetamine', 'marihuana', 'a-pvp', 'lidocaïne', 'steroïden', 'anabole', 'pep', 'xtc/mdma', 'paracetamol', 'amfetamines', 'fenacetine', 'pillen)', 'temazepam', 'crystal', 'gbl', 'kamagra', '(xtc)', 'methylfenidaat', 'opiaten', 'inositol', 'mdma,', 'cannabis', '(amfetamine)', 'procaïne', 'weed', '(cocaïne', 'ritalin', '(speed)', '(mdma', 'harddrugs', 'amfetamine)', 'viagra', '(met)amfetamine', 'xtc-', 'versnijdingsmiddel', 'tabletten', 'cocaine', 'capsules', 'hasj', 'coke', 'oxycodon', '2c-b', 'mdma-poeder', 'xtc,', 'cocaïne;', 'xtc-pil', 'pure', 'dexamfetamine', 'valium', '5793847)', 'wiet', '‘vieze’', '34-methyleendioxymethamfetamine', 'meth', 'amfetamine;', 'pmma', 'drugs', 'xtc-pillen,', 'mdma;', 'mdma/xtc', 'speed/amfetamine', 'heroïne)', 'opium', 'sildenafil', 'hash', 'heroïne,', '(halve', 'codeïne', 'methyleendioxymethylamphemtamine', '1375000', 'lorazepam', 'heroïne;', 'amfetamine,', 'benzodiazepinen', 'heroine', 'mapa', 'pil']

# %% [markdown]
# # Sandbox
